# %%
import pandas as pd
import numpy as np

# %%
hsv_one_df = pd.read_json('hsv_one_df.json')

# %%
hsv_one_df = hsv_one_df.reindex(range(0, len(hsv_one_df)))

# %%
hsv_one_df['LBXHE1'] = hsv_one_df['LBXHE1'].where(hsv_one_df['LBXHE1'] != 2, 0)

# %%
indices = np.random.choice(hsv_one_df[hsv_one_df['LBXHE1']==1].index,
                           int(0.8*len(hsv_one_df[hsv_one_df['LBXHE1']==1])), replace = False) 
flu = np.zeros(hsv_one_df.shape[0], dtype=int)

# %%
for index in indices:
    flu[index] = 1
hsv_one_df['Flu'] = flu
hsv_one_df = hsv_one_df.set_index('SEQN')
hsv_one_df.head()
# Out:
#        LBXHE1  RIAGENDR  RIDAGEYR  DMQMILIZ  DMQADFC  DMDEDUC3  DMDEDUC2  \
# SEQN
# 83736       1         2        42         2        0         0         4
# 83741       1         1        22         2        0         0         4
# 83742       1         2        32         2        0         0         4
# 83743       0         1        18         2        0        11         0
# 83745       0         2        15         0        0         9         0
#
#        DMDMARTL  DMDHHSIZ  DMDFMSIZ ...   RHQ570  RHQ580  RHQ596  SLD012  \
# SEQN                                ...
# 83736         3         5         5 ...        0       0       0     0.0
# 83741         5         3         3 ...        0       0       0     6.5
# 83742         1         4         4 ...        0       0       0     8.0
# 83743         0         3         3 ...        0       0       0     6.5
# 83745         0         3         3 ...        0       0       0     0.0
#
# ...

# %%
hsv_one_df.to_json('hsv_one_finale.json')
